# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url =  "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
           
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),                         
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | ostrovnoy
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | vardo
# Processing Record 10 of Set 1 | clyde river
# Processing Record 11 of Set 1 | isangel
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | faanui
# Processing Record 14 of Set 1 | tuy hoa
# Processing Record 15 of Set 1 | saint george
# Processing Record 16 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | sambava
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | mwingi
# Processing Record 25 of Set 1 | aswan
# Processing Record 26 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 1 | ancud
# Processing Record 28 of Set 1 | port hardy
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | rio gallegos
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | belaya gora
# Processing Record 33 of Set 1 | orel-izumrud
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | umm lajj
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | jaciara
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | hasaki
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | constitucion
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | hofn
# Processing Record 46 of Set 1 | wanaka
# Processing Record 47 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | karatau
# Processing Record 1 of Set 2 | sovetskaya
# Processing Record 2 of Set 2 | beloha
# Processing Record 3 of Set 2 | taltal
# Processing Record 4 of Set 2 | nosy varika
# Processing Record 5 of Set 2 | sorong
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | ilulissat
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | pangnirtung
# Processing Record 10 of Set 2 | wajima
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 15 of Set 2 | saint-michel-des-saints
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | pingliang
# Processing Record 19 of Set 2 | wazzan
# City not found. Skipping...
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | shache
# Processing Record 22 of Set 2 | fairbanks
# Processing Record 23 of Set 2 | muros
# Processing Record 24 of Set 2 | kutum
# Processing Record 25 of Set 2 | biak
# Processing Record 26 of Set 2 | tual
# Processing Record 27 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 2 | rovnoye
# Processing Record 29 of Set 2 | serenje
# Processing Record 30 of Set 2 | lagoa
# Processing Record 31 of Set 2 | vila velha
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | nanuque
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 2 | puerto penasco
# Processing Record 38 of Set 2 | sur
# Processing Record 39 of Set 2 | avera
# Processing Record 40 of Set 2 | vrangel
# Processing Record 41 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 2 | honningsvag
# Processing Record 44 of Set 2 | torbay
# Processing Record 45 of Set 2 | talnakh
# Processing Record 46 of Set 2 | haukipudas
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | nouakchott
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | kavaratti
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | coquimbo
# Processing Record 6 of Set 3 | tasiilaq
# Processing Record 7 of Set 3 | chapais
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | thompson
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | vila franca do campo
# Processing Record 12 of Set 3 | dosso
# Processing Record 13 of Set 3 | puerto escondido
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | severo-kurilsk
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | abha
# Processing Record 18 of Set 3 | henties bay
# Processing Record 19 of Set 3 | ribeira grande
# Processing Record 20 of Set 3 | auki
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | prado
# Processing Record 23 of Set 3 | dalian
# Processing Record 24 of Set 3 | zwedru
# Processing Record 25 of Set 3 | demyansk
# Processing Record 26 of Set 3 | gravdal
# Processing Record 27 of Set 3 | miramar
# Processing Record 28 of Set 3 | san roque
# Processing Record 29 of Set 3 | jamestown
# Processing Record 30 of Set 3 | ashington
# Processing Record 31 of Set 3 | east london
# Processing Record 32 of Set 3 | guane
# Processing Record 33 of Set 3 | busselton
# Processing Record 34 of Set 3 | yulara
# Processing Record 35 of Set 3 | zaykovo
# Processing Record 36 of Set 3 | mwinilunga
# Processing Record 37 of Set 3 | port elizabeth
# Processing Record 38 of Set 3 | nalut
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | marsh harbour
# Processing Record 42 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 3 | roncesvalles
# Processing Record 44 of Set 3 | bilma
# Processing Record 45 of Set 3 | kuytun
# Processing Record 46 of Set 3 | bethel
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | miri
# Processing Record 49 of Set 3 | nouadhibou
# Processing Record 50 of Set 3 | karachi
# Processing Record 1 of Set 4 | bathsheba
# Processing Record 2 of Set 4 | salalah
# Processing Record 3 of Set 4 | limbang
# Processing Record 4 of Set 4 | igarka
# Processing Record 5 of Set 4 | puerto madryn
# Processing Record 6 of Set 4 | payo
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | shenjiamen
# Processing Record 9 of Set 4 | bogorodskoye
# Processing Record 10 of Set 4 | rawson
# Processing Record 11 of Set 4 | komsomolskiy
# Processing Record 12 of Set 4 | banda aceh
# Processing Record 13 of Set 4 | aklavik
# Processing Record 14 of Set 4 | lasa
# Processing Record 15 of Set 4 | akyab
# Processing Record 16 of Set 4 | sorland
# Processing Record 17 of Set 4 | celestun
# Processing Record 18 of Set 4 | liuhe
# Processing Record 19 of Set 4 | mnogovershinnyy
# Processing Record 20 of Set 4 | tessalit
# Processing Record 21 of Set 4 | la ronge
# Processing Record 22 of Set 4 | ixtapa
# Processing Record 23 of Set 4 | carauari
# Processing Record 24 of Set 4 | pevek
# Processing Record 25 of Set 4 | sorso
# Processing Record 26 of Set 4 | lazaro cardenas
# Processing Record 27 of Set 4 | horadiz
# Processing Record 28 of Set 4 | bonfim
# Processing Record 29 of Set 4 | svetlyy
# Processing Record 30 of Set 4 | swellendam
# Processing Record 31 of Set 4 | yermakovskoye
# Processing Record 32 of Set 4 | hermanus
# Processing Record 33 of Set 4 | santa maria
# Processing Record 34 of Set 4 | ouadda
# Processing Record 35 of Set 4 | anadyr
# Processing Record 36 of Set 4 | mason city
# Processing Record 37 of Set 4 | caravelas
# Processing Record 38 of Set 4 | longonjo
# Processing Record 39 of Set 4 | tuatapere
# Processing Record 40 of Set 4 | oyem
# Processing Record 41 of Set 4 | mumford
# Processing Record 42 of Set 4 | labuhan
# Processing Record 43 of Set 4 | san pedro
# Processing Record 44 of Set 4 | kruisfontein
# Processing Record 45 of Set 4 | callaguip
# Processing Record 46 of Set 4 | abong mbang
# Processing Record 47 of Set 4 | miandrivazo
# Processing Record 48 of Set 4 | kavieng
# Processing Record 49 of Set 4 | broni
# Processing Record 50 of Set 4 | hobyo
# Processing Record 1 of Set 5 | cape town
# Processing Record 2 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 5 | wilmington
# Processing Record 4 of Set 5 | geraldton
# Processing Record 5 of Set 5 | pisco
# Processing Record 6 of Set 5 | muli
# Processing Record 7 of Set 5 | nyurba
# Processing Record 8 of Set 5 | mahebourg
# Processing Record 9 of Set 5 | arak
# Processing Record 10 of Set 5 | lebanon
# Processing Record 11 of Set 5 | shelburne
# Processing Record 12 of Set 5 | cherskiy
# Processing Record 13 of Set 5 | umarkot
# Processing Record 14 of Set 5 | hollywood
# Processing Record 15 of Set 5 | fortuna
# Processing Record 16 of Set 5 | atasu
# Processing Record 17 of Set 5 | portland
# Processing Record 18 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | antofagasta
# Processing Record 21 of Set 5 | half moon bay
# Processing Record 22 of Set 5 | airai
# Processing Record 23 of Set 5 | great yarmouth
# Processing Record 24 of Set 5 | kurilsk
# Processing Record 25 of Set 5 | esperance
# Processing Record 26 of Set 5 | tendo
# Processing Record 27 of Set 5 | lhokseumawe
# Processing Record 28 of Set 5 | hualmay
# Processing Record 29 of Set 5 | ayan
# Processing Record 30 of Set 5 | greenock
# Processing Record 31 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 5 | hamilton
# Processing Record 33 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 5 | salym
# Processing Record 35 of Set 5 | vao
# Processing Record 36 of Set 5 | villazon
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | sakakah
# Processing Record 39 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 5 | upernavik
# Processing Record 41 of Set 5 | klaksvik
# Processing Record 42 of Set 5 | khasan
# Processing Record 43 of Set 5 | dukat
# Processing Record 44 of Set 5 | yenagoa
# Processing Record 45 of Set 5 | shingu
# Processing Record 46 of Set 5 | mount gambier
# Processing Record 47 of Set 5 | nome
# Processing Record 48 of Set 5 | saskylakh
# Processing Record 49 of Set 5 | buta
# Processing Record 50 of Set 5 | rehlingen-siersburg
# Processing Record 1 of Set 6 | mandalgovi
# Processing Record 2 of Set 6 | lata
# Processing Record 3 of Set 6 | comodoro rivadavia
# Processing Record 4 of Set 6 | campo verde
# Processing Record 5 of Set 6 | gunjur
# Processing Record 6 of Set 6 | sitka
# Processing Record 7 of Set 6 | santa cruz
# Processing Record 8 of Set 6 | pacific grove
# Processing Record 9 of Set 6 | raga
# Processing Record 10 of Set 6 | conceicao do araguaia
# Processing Record 11 of Set 6 | mehamn
# Processing Record 12 of Set 6 | lompoc
# Processing Record 13 of Set 6 | salta
# Processing Record 14 of Set 6 | mashhad
# Processing Record 15 of Set 6 | chara
# Processing Record 16 of Set 6 | nanortalik
# Processing Record 17 of Set 6 | jurm
# Processing Record 18 of Set 6 | bambous virieux
# Processing Record 19 of Set 6 | teguldet
# Processing Record 20 of Set 6 | la palma
# Processing Record 21 of Set 6 | sept-iles
# Processing Record 22 of Set 6 | thinadhoo
# Processing Record 23 of Set 6 | sakaraha
# Processing Record 24 of Set 6 | georgetown
# Processing Record 25 of Set 6 | goderich
# Processing Record 26 of Set 6 | russell
# Processing Record 27 of Set 6 | jalingo
# Processing Record 28 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 6 | quatre cocos
# Processing Record 30 of Set 6 | erzin
# Processing Record 31 of Set 6 | prince rupert
# Processing Record 32 of Set 6 | guaymitas
# Processing Record 33 of Set 6 | balakhta
# Processing Record 34 of Set 6 | khatanga
# Processing Record 35 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 6 | armenia
# Processing Record 37 of Set 6 | bilibino
# Processing Record 38 of Set 6 | imbituba
# Processing Record 39 of Set 6 | flinders
# Processing Record 40 of Set 6 | vodnyy
# Processing Record 41 of Set 6 | san quintin
# Processing Record 42 of Set 6 | kudahuvadhoo
# Processing Record 43 of Set 6 | evensk
# Processing Record 44 of Set 6 | laerdalsoyri
# Processing Record 45 of Set 6 | sabha
# Processing Record 46 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 47 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 6 | coahuayana
# Processing Record 49 of Set 6 | manhattan
# Processing Record 50 of Set 6 | mogadishu
# Processing Record 1 of Set 7 | linshui
# Processing Record 2 of Set 7 | zhicheng
# Processing Record 3 of Set 7 | socorro
# Processing Record 4 of Set 7 | tilichiki
# Processing Record 5 of Set 7 | khani
# Processing Record 6 of Set 7 | karasjok
# Processing Record 7 of Set 7 | sfantu gheorghe
# Processing Record 8 of Set 7 | leh
# Processing Record 9 of Set 7 | phetchabun
# Processing Record 10 of Set 7 | abu samrah
# Processing Record 11 of Set 7 | tabou
# Processing Record 12 of Set 7 | northam
# Processing Record 13 of Set 7 | norman wells
# Processing Record 14 of Set 7 | pasni
# Processing Record 15 of Set 7 | butte
# Processing Record 16 of Set 7 | wadi maliz
# Processing Record 17 of Set 7 | andenes
# Processing Record 18 of Set 7 | cap malheureux
# Processing Record 19 of Set 7 | mpika
# Processing Record 20 of Set 7 | margate
# Processing Record 21 of Set 7 | lincoln
# Processing Record 22 of Set 7 | ballina
# Processing Record 23 of Set 7 | westport
# Processing Record 24 of Set 7 | angoche
# Processing Record 25 of Set 7 | bambanglipuro
# Processing Record 26 of Set 7 | talakan
# Processing Record 27 of Set 7 | plettenberg bay
# Processing Record 28 of Set 7 | truth or consequences
# Processing Record 29 of Set 7 | berlevag
# Processing Record 30 of Set 7 | yaan
# Processing Record 31 of Set 7 | san ramon de la nueva oran
# Processing Record 32 of Set 7 | atar
# Processing Record 33 of Set 7 | zalantun
# Processing Record 34 of Set 7 | makat
# Processing Record 35 of Set 7 | dalianwan
# Processing Record 36 of Set 7 | vilyuysk
# Processing Record 37 of Set 7 | saint-georges
# Processing Record 38 of Set 7 | port lincoln
# Processing Record 39 of Set 7 | pokosnoye
# Processing Record 40 of Set 7 | hambantota
# Processing Record 41 of Set 7 | phan thiet
# Processing Record 42 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 7 | lipari
# Processing Record 44 of Set 7 | sao joao da barra
# Processing Record 45 of Set 7 | faya
# Processing Record 46 of Set 7 | jumla
# Processing Record 47 of Set 7 | narsaq
# Processing Record 48 of Set 7 | rodeo
# Processing Record 49 of Set 7 | gombong
# Processing Record 50 of Set 7 | san policarpo
# Processing Record 1 of Set 8 | whyalla
# Processing Record 2 of Set 8 | west wendover
# Processing Record 3 of Set 8 | bonthe
# Processing Record 4 of Set 8 | saint anthony
# Processing Record 5 of Set 8 | saint-pierre
# Processing Record 6 of Set 8 | pimampiro
# Processing Record 7 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 8 | edd
# Processing Record 9 of Set 8 | grindavik
# Processing Record 10 of Set 8 | lyndon
# Processing Record 11 of Set 8 | lahad datu
# Processing Record 12 of Set 8 | baykit
# Processing Record 13 of Set 8 | adrar
# Processing Record 14 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 8 | aguimes
# Processing Record 16 of Set 8 | bereda
# Processing Record 17 of Set 8 | zhitikara
# City not found. Skipping...
# Processing Record 18 of Set 8 | puerto pinasco
# City not found. Skipping...
# Processing Record 19 of Set 8 | los llanos de aridane
# Processing Record 20 of Set 8 | xichang
# Processing Record 21 of Set 8 | lavrentiya
# Processing Record 22 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 8 | port blair
# Processing Record 24 of Set 8 | lake havasu city
# Processing Record 25 of Set 8 | sarankhola
# Processing Record 26 of Set 8 | bardiyah
# Processing Record 27 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 8 | motygino
# Processing Record 29 of Set 8 | drovyanaya
# Processing Record 30 of Set 8 | ponta delgada
# Processing Record 31 of Set 8 | sembakung
# Processing Record 32 of Set 8 | zilair
# Processing Record 33 of Set 8 | lensk
# Processing Record 34 of Set 8 | kargasok
# Processing Record 35 of Set 8 | sinnamary
# Processing Record 36 of Set 8 | barcelona
# Processing Record 37 of Set 8 | kiunga
# Processing Record 38 of Set 8 | rocha
# Processing Record 39 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 8 | paamiut
# Processing Record 41 of Set 8 | lovozero
# Processing Record 42 of Set 8 | krasnoselkup
# Processing Record 43 of Set 8 | wajid
# Processing Record 44 of Set 8 | manzhouli
# Processing Record 45 of Set 8 | shuiji
# Processing Record 46 of Set 8 | el tigre
# Processing Record 47 of Set 8 | luba
# Processing Record 48 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 8 | cagamutan
# City not found. Skipping...
# Processing Record 50 of Set 8 | dumai
# Processing Record 1 of Set 9 | cedar city
# Processing Record 2 of Set 9 | padang
# Processing Record 3 of Set 9 | guerrero negro
# Processing Record 4 of Set 9 | bom jesus
# Processing Record 5 of Set 9 | santarem
# Processing Record 6 of Set 9 | amahai
# Processing Record 7 of Set 9 | san miguel
# Processing Record 8 of Set 9 | kamogata
# Processing Record 9 of Set 9 | smidovich
# Processing Record 10 of Set 9 | hami
# Processing Record 11 of Set 9 | kununurra
# Processing Record 12 of Set 9 | afantou
# Processing Record 13 of Set 9 | deputatskiy
# Processing Record 14 of Set 9 | okhotsk
# Processing Record 15 of Set 9 | alaverdi
# Processing Record 16 of Set 9 | huarmey
# Processing Record 17 of Set 9 | bonaventure
# Processing Record 18 of Set 9 | laguna
# Processing Record 19 of Set 9 | san cristobal
# Processing Record 20 of Set 9 | dali
# Processing Record 21 of Set 9 | beaupre
# Processing Record 22 of Set 9 | abnub
# Processing Record 23 of Set 9 | morgan hill
# Processing Record 24 of Set 9 | awbari
# Processing Record 25 of Set 9 | ikungi
# Processing Record 26 of Set 9 | macklin
# Processing Record 27 of Set 9 | harper
# Processing Record 28 of Set 9 | afyonkarahisar
# Processing Record 29 of Set 9 | hokitika
# Processing Record 30 of Set 9 | mackay
# Processing Record 31 of Set 9 | neepawa
# Processing Record 32 of Set 9 | puerto lleras
# Processing Record 33 of Set 9 | bay roberts
# Processing Record 34 of Set 9 | magadan
# Processing Record 35 of Set 9 | ayios kirikos
# City not found. Skipping...
# Processing Record 36 of Set 9 | yarada
# Processing Record 37 of Set 9 | kjopsvik
# Processing Record 38 of Set 9 | honiara
# Processing Record 39 of Set 9 | aksarka
# Processing Record 40 of Set 9 | san patricio
# Processing Record 41 of Set 9 | buala
# Processing Record 42 of Set 9 | trunovskoye
# Processing Record 43 of Set 9 | batticaloa
# Processing Record 44 of Set 9 | hagere hiywet
# Processing Record 45 of Set 9 | santiago del estero
# Processing Record 46 of Set 9 | guelengdeng
# City not found. Skipping...
# Processing Record 47 of Set 9 | fort morgan
# Processing Record 48 of Set 9 | cuitareo
# Processing Record 49 of Set 9 | pangody
# Processing Record 50 of Set 9 | tefe
# Processing Record 1 of Set 10 | kongsvinger
# Processing Record 2 of Set 10 | shaoguan
# Processing Record 3 of Set 10 | ahipara
# Processing Record 4 of Set 10 | mattru
# Processing Record 5 of Set 10 | waipawa
# Processing Record 6 of Set 10 | santa clarita
# Processing Record 7 of Set 10 | itarema
# Processing Record 8 of Set 10 | kolodenka
# Processing Record 9 of Set 10 | upington
# Processing Record 10 of Set 10 | bryukhovychi
# Processing Record 11 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 10 | vallenar
# Processing Record 13 of Set 10 | ewa beach
# Processing Record 14 of Set 10 | belyy yar
# Processing Record 15 of Set 10 | san fernando
# Processing Record 16 of Set 10 | kampong thum
# Processing Record 17 of Set 10 | ganzhou
# Processing Record 18 of Set 10 | coihaique
# Processing Record 19 of Set 10 | dingle
# Processing Record 20 of Set 10 | alta floresta
# Processing Record 21 of Set 10 | sibut
# Processing Record 22 of Set 10 | yar-sale
# Processing Record 23 of Set 10 | merauke
# Processing Record 24 of Set 10 | sterling
# Processing Record 25 of Set 10 | dunedin
# Processing Record 26 of Set 10 | poum
# Processing Record 27 of Set 10 | mantua
# Processing Record 28 of Set 10 | bolshaya dzhalga
# Processing Record 29 of Set 10 | usinsk
# Processing Record 30 of Set 10 | manta
# Processing Record 31 of Set 10 | tavricheskoye
# Processing Record 32 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 10 | khuldabad
# Processing Record 34 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 35 of Set 10 | naze
# Processing Record 36 of Set 10 | moerai
# Processing Record 37 of Set 10 | nemuro
# Processing Record 38 of Set 10 | jackson
# Processing Record 39 of Set 10 | enshi
# Processing Record 40 of Set 10 | sao paulo de olivenca
# Processing Record 41 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 10 | sola
# Processing Record 43 of Set 10 | graham
# Processing Record 44 of Set 10 | bronnoysund
# Processing Record 45 of Set 10 | khagrachari
# City not found. Skipping...
# Processing Record 46 of Set 10 | ketchikan
# Processing Record 47 of Set 10 | jardim
# Processing Record 48 of Set 10 | kenai
# Processing Record 49 of Set 10 | kyzyl-suu
# Processing Record 50 of Set 10 | ahar
# Processing Record 1 of Set 11 | college
# Processing Record 2 of Set 11 | campo largo
# Processing Record 3 of Set 11 | husavik
# Processing Record 4 of Set 11 | zhangjiakou
# Processing Record 5 of Set 11 | shangzhi
# Processing Record 6 of Set 11 | myitkyina
# Processing Record 7 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 11 | talaya
# Processing Record 9 of Set 11 | lorengau
# Processing Record 10 of Set 11 | lac du bonnet
# Processing Record 11 of Set 11 | namibe
# Processing Record 12 of Set 11 | high level
# Processing Record 13 of Set 11 | capitao poco
# Processing Record 14 of Set 11 | sault sainte marie
# Processing Record 15 of Set 11 | mendoza
# Processing Record 16 of Set 11 | calategas
# City not found. Skipping...
# Processing Record 17 of Set 11 | scarborough
# Processing Record 18 of Set 11 | sao filipe
# Processing Record 19 of Set 11 | arroyo
# Processing Record 20 of Set 11 | luderitz
# Processing Record 21 of Set 11 | naryan-mar
# Processing Record 22 of Set 11 | wawa
# Processing Record 23 of Set 11 | cowansville
# Processing Record 24 of Set 11 | zhigansk
# Processing Record 25 of Set 11 | oranjestad
# Processing Record 26 of Set 11 | north bend
# Processing Record 27 of Set 11 | karasburg
# Processing Record 28 of Set 11 | maniitsoq
# Processing Record 29 of Set 11 | wuda
# Processing Record 30 of Set 11 | lerwick
# Processing Record 31 of Set 11 | egvekinot
# Processing Record 32 of Set 11 | roebourne
# Processing Record 33 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 11 | ust-maya
# Processing Record 35 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 36 of Set 11 | gazojak
# Processing Record 37 of Set 11 | urengoy
# Processing Record 38 of Set 11 | tyrma
# Processing Record 39 of Set 11 | petatlan
# Processing Record 40 of Set 11 | abu kamal
# Processing Record 41 of Set 11 | marsabit
# Processing Record 42 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 11 | maldonado
# Processing Record 44 of Set 11 | ilheus
# Processing Record 45 of Set 11 | haines junction
# Processing Record 46 of Set 11 | motril
# Processing Record 47 of Set 11 | uroteppa
# City not found. Skipping...
# Processing Record 48 of Set 11 | berezovyy
# Processing Record 49 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 11 | miajadas
# Processing Record 1 of Set 12 | grandola
# Processing Record 2 of Set 12 | anklesvar
# City not found. Skipping...
# Processing Record 3 of Set 12 | novi sanzhary
# Processing Record 4 of Set 12 | kieta
# Processing Record 5 of Set 12 | udachnyy
# Processing Record 6 of Set 12 | puerto colombia
# Processing Record 7 of Set 12 | pochutla
# Processing Record 8 of Set 12 | muzquiz
# City not found. Skipping...
# Processing Record 9 of Set 12 | haimen
# Processing Record 10 of Set 12 | svetlogorsk
# Processing Record 11 of Set 12 | ranot
# Processing Record 12 of Set 12 | azrow
# City not found. Skipping...
# Processing Record 13 of Set 12 | ngunguru
# Processing Record 14 of Set 12 | kirakira
# Processing Record 15 of Set 12 | siavonga
# Processing Record 16 of Set 12 | yate
# Processing Record 17 of Set 12 | camacha
# Processing Record 18 of Set 12 | progreso
# Processing Record 19 of Set 12 | vidim
# Processing Record 20 of Set 12 | mitchell
# Processing Record 21 of Set 12 | aljezur
# Processing Record 22 of Set 12 | qinzhou
# Processing Record 23 of Set 12 | dakar
# Processing Record 24 of Set 12 | touros
# Processing Record 25 of Set 12 | sorkjosen
# Processing Record 26 of Set 12 | san rafael
# Processing Record 27 of Set 12 | gedo
# Processing Record 28 of Set 12 | cabo san lucas
# Processing Record 29 of Set 12 | tarauaca
# Processing Record 30 of Set 12 | sainte-maxime
# Processing Record 31 of Set 12 | obera
# Processing Record 32 of Set 12 | tornio
# Processing Record 33 of Set 12 | cukai
# Processing Record 34 of Set 12 | mukhen
# Processing Record 35 of Set 12 | saint-joseph
# Processing Record 36 of Set 12 | berestechko
# Processing Record 37 of Set 12 | saurimo
# Processing Record 38 of Set 12 | meulaboh
# Processing Record 39 of Set 12 | hue
# Processing Record 40 of Set 12 | camargo
# Processing Record 41 of Set 12 | pervomayskoye
# Processing Record 42 of Set 12 | tinaquillo
# Processing Record 43 of Set 12 | parras
# City not found. Skipping...
# Processing Record 44 of Set 12 | svetlaya
# Processing Record 45 of Set 12 | fort collins
# Processing Record 46 of Set 12 | whitehorse
# Processing Record 47 of Set 12 | polson
# Processing Record 48 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 12 | kazachinskoye
# Processing Record 50 of Set 12 | gamba
# Processing Record 1 of Set 13 | baraboo
# Processing Record 2 of Set 13 | asau
# Processing Record 3 of Set 13 | agadez
# Processing Record 4 of Set 13 | kormilovka
# Processing Record 5 of Set 13 | charleston
# Processing Record 6 of Set 13 | zaliztsi
# Processing Record 7 of Set 13 | beyneu
# Processing Record 8 of Set 13 | takoradi
# Processing Record 9 of Set 13 | kahului
# Processing Record 10 of Set 13 | ternate
# Processing Record 11 of Set 13 | luang prabang
# Processing Record 12 of Set 13 | mokhsogollokh
# Processing Record 13 of Set 13 | katsuura
# Processing Record 14 of Set 13 | luganville
# Processing Record 15 of Set 13 | koumac
# Processing Record 16 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 13 | alofi
# Processing Record 18 of Set 13 | ardakan
# Processing Record 19 of Set 13 | isabela
# Processing Record 20 of Set 13 | senno
# Processing Record 21 of Set 13 | krasnoborsk
# Processing Record 22 of Set 13 | virginia beach
# Processing Record 23 of Set 13 | shihezi
# Processing Record 24 of Set 13 | bongandanga
# Processing Record 25 of Set 13 | tokur
# Processing Record 26 of Set 13 | pitimbu
# Processing Record 27 of Set 13 | ulkan
# Processing Record 28 of Set 13 | alice springs
# Processing Record 29 of Set 13 | makakilo city
# Processing Record 30 of Set 13 | saquena
# Processing Record 31 of Set 13 | port hedland
# Processing Record 32 of Set 13 | winslow
# Processing Record 33 of Set 13 | briancon
# Processing Record 34 of Set 13 | skovde
# City not found. Skipping...
# Processing Record 35 of Set 13 | san felipe
# Processing Record 36 of Set 13 | sakhon nakhon
# Processing Record 37 of Set 13 | torres
# Processing Record 38 of Set 13 | payyannur
# Processing Record 39 of Set 13 | burica
# City not found. Skipping...
# Processing Record 40 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 13 | bubaque
# Processing Record 42 of Set 13 | brovst
# Processing Record 43 of Set 13 | praia
# Processing Record 44 of Set 13 | chastyye
# Processing Record 45 of Set 13 | porto novo
# Processing Record 46 of Set 13 | sesheke
# Processing Record 47 of Set 13 | cabatuan
# Processing Record 48 of Set 13 | gamboma
# Processing Record 49 of Set 13 | panaba
# Processing Record 50 of Set 13 | buraydah
# Processing Record 1 of Set 14 | williams lake
# Processing Record 2 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 3 of Set 14 | gizo
# Processing Record 4 of Set 14 | sao miguel do araguaia
# Processing Record 5 of Set 14 | cervo
# Processing Record 6 of Set 14 | chicama
# Processing Record 7 of Set 14 | kaabong
# Processing Record 8 of Set 14 | stornoway
# Processing Record 9 of Set 14 | porciuncula
# Processing Record 10 of Set 14 | azuaga
# Processing Record 11 of Set 14 | menongue
# Processing Record 12 of Set 14 | bowen
# Processing Record 13 of Set 14 | bairnsdale
# Processing Record 14 of Set 14 | thai nguyen
# Processing Record 15 of Set 14 | gat
# Processing Record 16 of Set 14 | tazovskiy
# Processing Record 17 of Set 14 | sabang
# Processing Record 18 of Set 14 | te anau
# Processing Record 19 of Set 14 | eenhana
# Processing Record 20 of Set 14 | ninghai
# Processing Record 21 of Set 14 | bac giang
# Processing Record 22 of Set 14 | vestmannaeyjar
# Processing Record 23 of Set 14 | inhambane
# Processing Record 24 of Set 14 | kochkurovo
# Processing Record 25 of Set 14 | fukuma
# Processing Record 26 of Set 14 | sao felix do xingu
# Processing Record 27 of Set 14 | killybegs
# Processing Record 28 of Set 14 | victor harbor
# Processing Record 29 of Set 14 | ormara
# Processing Record 30 of Set 14 | coari
# Processing Record 31 of Set 14 | kamenka
# Processing Record 32 of Set 14 | yuncheng
# Processing Record 33 of Set 14 | klyavlino
# Processing Record 34 of Set 14 | san borja
# Processing Record 35 of Set 14 | metro
# Processing Record 36 of Set 14 | japura
# Processing Record 37 of Set 14 | umm kaddadah
# Processing Record 38 of Set 14 | belmonte
# Processing Record 39 of Set 14 | matara
# Processing Record 40 of Set 14 | revelstoke
# Processing Record 41 of Set 14 | yanam
# Processing Record 42 of Set 14 | machali
# Processing Record 43 of Set 14 | kawardha
# Processing Record 44 of Set 14 | caxito
# Processing Record 45 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 46 of Set 14 | grajau
# Processing Record 47 of Set 14 | iracoubo
# Processing Record 48 of Set 14 | high rock
# Processing Record 49 of Set 14 | milkovo
# Processing Record 50 of Set 14 | warri
# Processing Record 1 of Set 15 | san zenon
# Processing Record 2 of Set 15 | kuandian
# Processing Record 3 of Set 15 | xining
# Processing Record 4 of Set 15 | seminole
# Processing Record 5 of Set 15 | magadi
# Processing Record 6 of Set 15 | tashla
# Processing Record 7 of Set 15 | ous
# Processing Record 8 of Set 15 | formosa
# Processing Record 9 of Set 15 | wanning
# Processing Record 10 of Set 15 | cecina
# Processing Record 11 of Set 15 | veraval
# Processing Record 12 of Set 15 | shakawe
# Processing Record 13 of Set 15 | yei
# Processing Record 14 of Set 15 | terrace
# Processing Record 15 of Set 15 | road town
# Processing Record 16 of Set 15 | capao da canoa
# Processing Record 17 of Set 15 | yalta
# Processing Record 18 of Set 15 | huntsville
# Processing Record 19 of Set 15 | adiake
# Processing Record 20 of Set 15 | kunashak
# Processing Record 21 of Set 15 | shanghai
# Processing Record 22 of Set 15 | san andres
# Processing Record 23 of Set 15 | havre-saint-pierre
# Processing Record 24 of Set 15 | copiapo
# Processing Record 25 of Set 15 | dudinka
# Processing Record 26 of Set 15 | the valley
# Processing Record 27 of Set 15 | itaituba
# Processing Record 28 of Set 15 | wagga wagga
# Processing Record 29 of Set 15 | sao jose dos pinhais
# Processing Record 30 of Set 15 | nazas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 670

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo -22.9661  -42.0278     69.31        84         100
# 1        Ostrovnoy  68.0531   39.5131     46.18        86          80
# 2          Rikitea -23.1203 -134.9692     69.35        63          69
# 3             Chuy -33.6971  -53.4616     58.86        84         100
# 4         Souillac -20.5167   57.5167     71.98        73          75
# 5       Nikolskoye  59.7035   30.7861     49.91        98         100
# 6            Vardo  70.3705   31.1107     42.78        81         100
# 7      Clyde River  70.4692  -68.5914     25.03        80         100
# 8          Isangel -19.5500  169.2667     80.71        78          75
# 9          Ushuaia -54.8000  -68.3000     40.66        87         100
#
#    Wind Speed Country      Current Description
# 0       12.86      BR          overcast clouds
# 1       16.17      RU            broken clouds
# 2       20.85      PF            broken clouds
# 3       12.19      UY          overcast clouds
# 4       10.36      MU            broken clouds
# 5        7.56      RU          overcast clouds
# 6       17.27      NO          overcast clouds
# 7       19.57      CA               light snow
# 8       11.50      VU            broken clouds
# 9       28.77      AR  light intensity drizzle

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     69.31        84         100
# 1        Ostrovnoy      RU  68.0531   39.5131     46.18        86          80
# 2          Rikitea      PF -23.1203 -134.9692     69.35        63          69
# 3             Chuy      UY -33.6971  -53.4616     58.86        84         100
# 4         Souillac      MU -20.5167   57.5167     71.98        73          75
#
#    Wind Speed Current Description
# 0       12.86     overcast clouds
# 1       16.17       broken clouds
# 2       20.85       broken clouds
# 3       12.19     overcast clouds
# 4       10.36       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index_label="City_ID")
